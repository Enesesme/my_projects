# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('scout_car.json', lines=True, orient=str)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %%
df.drop(['Country version','url','Model Code','Emission Class', '\nComfort & Convenience\n','\nEntertainment & Media\n', 
'\nExtras\n', '\nSafety & Security\n','kW','description', 'Emission Label','null','First Registration','prev_owner',
'Electricity consumption', 'Last Service Date', 'Other Fuel Types','Availability', 'Last Timing Belt Service Date', 
'Available from','Inspection new', 'Warranty','Offer Number','Next Inspection','Paint Type','Nr. of Seats','vat','Type',
'Body Color Original','body_type','Full Service','Upholstery','CO2 Emission','Non-smoking Vehicle', 'Make', 'Model','Weight'], axis = 1 , inplace = True)

# %%
df.head()
# Out:
#   make_model                                  short_description  price  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima  15770
# 1    Audi A1                                     1.8 TFSI sport  14500
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...  14640
# 3    Audi A1                            1.4 TDi Design S tronic  14500
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...  16790
#
#           km registration      hp Previous Owners       Body Color  \
# 0  56,013 km      01/2016   66 kW           \n2\n  [\n, Black, \n]
# 1  80,000 km      03/2017  141 kW             NaN    [\n, Red, \n]
# 2  83,450 km      02/2016   85 kW           \n1\n  [\n, Black, \n]
# 3  73,000 km      08/2016   66 kW           \n1\n  [\n, Brown, \n]
# 4  16,200 km      05/2016   66 kW           \n1\n  [\n, Black, \n]
#
#                Body Nr. of Doors         Gearing Type    Displacement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make_model         15919 non-null  object
#  1   short_description  15873 non-null  object
#  2   price              15919 non-null  int64
#  3   km                 15919 non-null  object
#  4   registration       15919 non-null  object
#  5   hp                 15919 non-null  object
#  6   Previous Owners    9279 non-null   object
#  7   Body Color         15322 non-null  object
#  8   Body               15859 non-null  object
#  9   Nr. of Doors       15707 non-null  object
#  10  Gearing Type       15919 non-null  object
#  11  Displacement       15423 non-null  object
#  12  Cylinders          10239 non-null  object
#  13  Drive chain        9061 non-null   object
#  14  Fuel               15919 non-null  object
#  15  Consumption        14013 non-null  object
# ...

# %%
df["km"] = df["km"].str.split("km").str[0]

# %%
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price       km registration      hp  \
# 0      15770  56,013       01/2016   66 kW
# ...

# %%
df["km"] = df["km"].str.replace(",","")
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration      hp  \
# 0      15770  56013       01/2016   66 kW
# ...

# %%
df["km"].unique() # km sütunu daha sonra int'e çevireceğiz.
# Out:
# array(['56013 ', '80000 ', '83450 ', ..., '2864 ', '1506 ', '57 '],
#       dtype=object)

# %%
df["kw"] = df["hp"]

# %%
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration      hp  \
# 0      15770  56013       01/2016   66 kW
# ...

# %%
df.drop("hp", axis=1 , inplace=True)
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration  \
# 0      15770  56013       01/2016
# ...

# %%
df["kw"] = df["kw"].str.split("kW").str[0]
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration  \
# 0      15770  56013       01/2016
# ...

# %%
df["Previous Owners"] = df["Previous Owners"].str.lstrip("\n")
df["Previous Owners"] = df["Previous Owners"].str.rstrip("\n")
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration Previous Owners       Body Color  \
# ...

# %%
df["Previous Owners"].value_counts(dropna=False)
# Out:
# 1      8101
# NaN    6870
# 2       766
# 0       163
# 3        17
# 4         2
# Name: Previous Owners, dtype: int64

# %%
def orta(i) :
    try :
        return i[1]
    except :
        return i

# %%
df["Body Color"] = df["Body Color"].apply(orta)
df["Body"] = df["Body"].apply(orta)
df["Gearing Type"] = df["Gearing Type"].apply(orta)
df["Fuel"] = df["Fuel"].apply(orta)
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration Previous Owners Body Color    Body  \
# ...

# %%
df.loc[df["Fuel"].str.contains("Diesel"), "Fuel"] = "Diesel"
df.loc[df["Fuel"].str.contains("CNG|Others|Biogas|Electric|Domestic|LPG"), "Fuel"] = "Others"
df.loc[df["Fuel"].str.contains("Benzine|Super|Gasoline"), "Fuel"] = "Benzine"
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration Previous Owners Body Color    Body  \
# ...

# %%
def ortadaki(k):
    try:
        return k[0]
    except :
        return k

# %%
df["Displacement"] = df["Displacement"].apply(ortadaki)
df["Displacement"] = df["Displacement"].str.strip("\n")
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration Previous Owners Body Color    Body  \
# ...

# %%
def ortada(l):
    try:
        return l[0]
    except :
        return l

# %%
df["Cylinders"] = df["Cylinders"].apply(ortada)
df["Cylinders"] = df["Cylinders"].str.strip("\n")
df["Drive chain"] = df["Drive chain"].apply(ortada)
df["Drive chain"] = df["Drive chain"].str.strip("\n")
df["Nr. of Doors"] = df["Nr. of Doors"].apply(ortada)
df["Nr. of Doors"] = df["Nr. of Doors"].str.strip("\n")
df["Gears"] = df["Gears"].apply(ortada)
df["Gears"] = df["Gears"].str.strip("\n")
df
# Out:
#            make_model                                  short_description  \
# 0             Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1             Audi A1                                     1.8 TFSI sport
# 2             Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3             Audi A1                            1.4 TDi Design S tronic
# 4             Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...               ...                                                ...
# 15914  Renault Espace              Blue dCi 200CV EDC Executive 4Control
# 15915  Renault Espace                TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916  Renault Espace  Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917  Renault Espace  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918  Renault Espace        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
#
#        price      km registration Previous Owners Body Color    Body  \
# ...

# %%
df["Consumption"].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                   1906
# [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]               304
# [[4.2 l/100 km (comb)], [5 l/100 km (city)], [3.7 l/100 km (country)]]                 276
# [[5.4 l/100 km (comb)], [6.8 l/100 km (city)], [4.5 l/100 km (country)]]               257
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make_model         15919 non-null  object
#  1   short_description  15873 non-null  object
#  2   price              15919 non-null  int64
#  3   km                 15919 non-null  object
#  4   registration       15919 non-null  object
#  5   Previous Owners    9049 non-null   object
#  6   Body Color         15322 non-null  object
#  7   Body               15859 non-null  object
#  8   Nr. of Doors       15707 non-null  object
#  9   Gearing Type       15919 non-null  object
#  10  Displacement       15423 non-null  object
#  11  Cylinders          10239 non-null  object
#  12  Drive chain        9061 non-null   object
#  13  Fuel               15919 non-null  object
#  14  Consumption        14013 non-null  object
#  15  Gears              11207 non-null  object
# ...
